# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# #Cleaning Non primed Data (use pickle in the future)

# %%
non_primed_survey = pd.read_csv("non-primed-q1.csv", encoding="ISO-8859-1")

# %%
non_primed_survey = non_primed_survey.iloc[1:,1:]

# %%
non_primed_survey
# Out:
#                                          Envisionÿ.1            Envisionÿ.2  \
# 1                                     Answer Options  Strongly Disagree (1)
# 2  I am confident a project team could really ach...                      1
# 3  I believe my score is above average compared t...                      2
# 4  Seeing an example high-scoring Envision projec...                      3
# 5  When considering the possible levels of achiev...                      1
# 6  I made my decisions based on previous work exp...                      2
# 7            Iÿwill use Envision on future projects.                      2
# 8                                  answered question      answered question
# 9                                   skipped question       skipped question
#
#          Envisionÿ.3        Envisionÿ.4        Envisionÿ.5  \
# 1                  2                  3                  4
# 2                  2                  7                  7
# ...

# %%
non_primed_survey.columns = non_primed_survey.iloc[0]

# %%
non_primed_survey = non_primed_survey.reindex(non_primed_survey.index.drop(1))

# %%
non_primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  \
# 2  I am confident a project team could really ach...                     1
# 3  I believe my score is above average compared t...                     2
# 4  Seeing an example high-scoring Envision projec...                     3
# 5  When considering the possible levels of achiev...                     1
# 6  I made my decisions based on previous work exp...                     2
# 7            Iÿwill use Envision on future projects.                     2
# 8                                  answered question     answered question
# 9                                   skipped question      skipped question
#
# 1                  2                  3                  4 Strongly Agree (5)  \
# 2                  2                  7                  7                  9
# 3                  4                 12                  5                  3
# ...

# %%
non_primed_survey = non_primed_survey.iloc[:6,:]

# %%
non_primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  2  \
# 2  I am confident a project team could really ach...                     1  2
# 3  I believe my score is above average compared t...                     2  4
# 4  Seeing an example high-scoring Envision projec...                     3  3
# 5  When considering the possible levels of achiev...                     1  1
# 6  I made my decisions based on previous work exp...                     2  3
# 7            Iÿwill use Envision on future projects.                     2  4
#
# 1   3   4 Strongly Agree (5) Rating Average Response Count
# 2   7   7                  9           3.81             26
# 3  12   5                  3           3.12             26
# 4   4  12                  4           3.42             26
# 5   4   8                 12           4.12             26
# 6   6   8                  7           3.58             26
# 7  14   4                  2           3.00             26

# %%
non_primed_survey.loc[7, 'Answer Options'] = "I will use Envision on future projects."
# Out:
# /Users/trippshealy/Documents/research/envision-role-model/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
non_primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  2  \
# 2  I am confident a project team could really ach...                     1  2
# 3  I believe my score is above average compared t...                     2  4
# 4  Seeing an example high-scoring Envision projec...                     3  3
# 5  When considering the possible levels of achiev...                     1  1
# 6  I made my decisions based on previous work exp...                     2  3
# 7            I will use Envision on future projects.                     2  4
#
# 1   3   4 Strongly Agree (5) Rating Average Response Count
# 2   7   7                  9           3.81             26
# 3  12   5                  3           3.12             26
# 4   4  12                  4           3.42             26
# 5   4   8                 12           4.12             26
# 6   6   8                  7           3.58             26
# 7  14   4                  2           3.00             26

# %% [markdown]
# saved to pickle

# %%
primed_survey = pd.read_csv("primed-q1.csv", encoding="ISO-8859-1")

# %%
primed_survey
# Out:
#                                             Envision  \
# 0                                      Please Answer
# 1                                     Answer Options
# 2  I am confident a project team could really ach...
# 3  I believe the Envision score I came up with is...
# 4  The Psomas Engineeringÿexample project motivat...
# 5  When considering the possible levels of achiev...
# 6  I made my decisions based on previous work exp...
# 7                 Iÿwill use Envision in the future.
# 8                                  answered question
# 9                                   skipped question
#
#                                           Envision.1             Envision.2  \
# 0                                      Please Answer          Please Answer
# 1                                     Answer Options  Strongly Disagree (1)
# 2  I am confident a project team could really ach...                      2
# ...

# %%
primed_survey = primed_survey.iloc[1:,1:]

# %%
primed_survey
# Out:
#                                           Envision.1             Envision.2  \
# 1                                     Answer Options  Strongly Disagree (1)
# 2  I am confident a project team could really ach...                      2
# 3  I believe the Envision score I came up with is...                      2
# 4  The Psomas Engineeringÿexample project motivat...                      1
# 5  When considering the possible levels of achiev...                      1
# 6  I made my decisions based on previous work exp...                      3
# 7                 Iÿwill use Envision in the future.                      0
# 8                                  answered question      answered question
# 9                                   skipped question       skipped question
#
#           Envision.3         Envision.4         Envision.5  \
# 1                  2                  3                  4
# 2                  0                  8                 12
# ...

# %%
primed_survey.columns = primed_survey.iloc[0]

# %%
primed_survey
# Out:
# 1                                     Answer Options  Strongly Disagree (1)  \
# 1                                     Answer Options  Strongly Disagree (1)
# 2  I am confident a project team could really ach...                      2
# 3  I believe the Envision score I came up with is...                      2
# 4  The Psomas Engineeringÿexample project motivat...                      1
# 5  When considering the possible levels of achiev...                      1
# 6  I made my decisions based on previous work exp...                      3
# 7                 Iÿwill use Envision in the future.                      0
# 8                                  answered question      answered question
# 9                                   skipped question       skipped question
#
# 1                  2                  3                  4  \
# 1                  2                  3                  4
# 2                  0                  8                 12
# ...

# %%
primed_survey = primed_survey.reindex(primed_survey.index.drop(1))

# %%
primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  \
# 2  I am confident a project team could really ach...                     2
# 3  I believe the Envision score I came up with is...                     2
# 4  The Psomas Engineeringÿexample project motivat...                     1
# 5  When considering the possible levels of achiev...                     1
# 6  I made my decisions based on previous work exp...                     3
# 7                 Iÿwill use Envision in the future.                     0
# 8                                  answered question     answered question
# 9                                   skipped question      skipped question
#
# 1                  2                  3                  4 Strongly Agree (5)  \
# 2                  0                  8                 12                  8
# 3                  3                 13                 11                  1
# ...

# %%
primed_survey = primed_survey.iloc[:6,:]

# %%
primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  2  \
# 2  I am confident a project team could really ach...                     2  0
# 3  I believe the Envision score I came up with is...                     2  3
# 4  The Psomas Engineeringÿexample project motivat...                     1  2
# 5  When considering the possible levels of achiev...                     1  1
# 6  I made my decisions based on previous work exp...                     3  3
# 7                 Iÿwill use Envision in the future.                     0  1
#
# 1   3   4 Strongly Agree (5) Rating Average Response Count
# 2   8  12                  8           3.80             30
# 3  13  11                  1           3.20             30
# 4   8  16                  3           3.60             30
# 5  11  10                  7           3.70             30
# 6  10  11                  3           3.27             30
# 7  20   7                  2           3.33             30

# %%
primed_survey.loc[7, 'Answer Options'] = "I will use Envision on future projects."
# Out:
# /Users/trippshealy/Documents/research/envision-role-model/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
primed_survey
# Out:
# 1                                     Answer Options Strongly Disagree (1)  2  \
# 2  I am confident a project team could really ach...                     2  0
# 3  I believe the Envision score I came up with is...                     2  3
# 4  The Psomas Engineeringÿexample project motivat...                     1  2
# 5  When considering the possible levels of achiev...                     1  1
# 6  I made my decisions based on previous work exp...                     3  3
# 7            I will use Envision on future projects.                     0  1
#
# 1   3   4 Strongly Agree (5) Rating Average Response Count
# 2   8  12                  8           3.80             30
# 3  13  11                  1           3.20             30
# 4   8  16                  3           3.60             30
# 5  11  10                  7           3.70             30
# 6  10  11                  3           3.27             30
# 7  20   7                  2           3.33             30

# %%
primed_survey.to_pickle("primed-q1.pickle")
